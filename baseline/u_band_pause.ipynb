# %%
import numpy as np
import sqlite3
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %%
con = sqlite3.connect("baseline_v3.2_10yrs.db")
df = pd.read_sql("select night from observations where filter='u'", con)
con.close()
yval = np.arange(df['night'].size)

fig, ax = plt.subplots()

ax.plot(df['night'], yval, label='v3.2')

con = sqlite3.connect("baseline_v3.3_10yrs.db")
df = pd.read_sql("select night from observations where filter='u'", con)
con.close()
yval = np.arange(df['night'].size)
ax.plot(df['night'], yval, label='v3.3')

ax.legend()

ax.set(xlabel='Night', ylabel='N u-band vists')
# Out:
# [Text(0.5, 0, 'Night'), Text(0, 0.5, 'N u-band vists')]
