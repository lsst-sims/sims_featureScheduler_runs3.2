# %%
import pandas as pd
import sqlite3
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np

# %%
filtername = 'u'

con = sqlite3.connect('u_threepy_v3.2_10yrs.db')
df = pd.read_sql('select night from observations where filter="%s"' % filtername, con)
con.close()

n = np.arange(df['night'].values.size)

plt.plot(df['night'], n)

con = sqlite3.connect('../baseline/baseline_v3.2_10yrs.db')
df = pd.read_sql('select night from observations where filter="%s"' % filtername, con)
con.close()

n = np.arange(df['night'].values.size)

plt.plot(df['night'], n)
